# %%
jack[1]
# jack[[1]]
# jack[‘1’]
# jack[[1, 1]]
# jack.loc[1]
# jack.loc[jack[1] == ‘fo’]
# jack[1, [‘1’, 1]]
# jack.loc[1,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 jack[1]
#
# NameError: name 'jack' is not defined
